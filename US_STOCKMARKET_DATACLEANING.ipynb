# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading CSV File

# %%
df=pd.read_csv('USStockMarketDataset.csv')

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0           0    2/2/2024              2.079               NaN
# 1           1    1/2/2024              2.050          161340.0
# 2           2  31-01-2024              2.100          142860.0
# 3           3  30-01-2024              2.077          139750.0
# 4           4  29-01-2024              2.490            3590.0
#
#    Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  \
# 0            72.28             NaN        3.8215          NaN     43,194.70
# 1            73.82        577940.0        3.8535          NaN     43,081.40
# 2            75.85        344490.0        3.9060          NaN     42,580.50
# 3            77.82        347240.0        3.9110          NaN     42,946.20
# 4            76.78        331930.0        3.8790          NaN     43,299.80
#
#    Bitcoin_Vol.  ... Berkshire_Price  Berkshire_Vol. Netflix_Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1009 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     990 non-null    float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        976 non-null    float64
#  8   Bitcoin_Price      1013 non-null   object
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   object
#  11  Platinum_Vol.      636 non-null    float64
#  12  Ethereum_Price     1013 non-null   object
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   object
#  15  Nasdaq_100_Price   1013 non-null   object
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isna()
# Out:
#       Unnamed: 0   Date  Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# 0          False  False              False              True            False
# 1          False  False              False             False            False
# 2          False  False              False             False            False
# 3          False  False              False             False            False
# 4          False  False              False             False            False
# ...          ...    ...                ...               ...              ...
# 1008       False  False              False             False            False
# 1009       False  False              False             False            False
# 1010       False  False              False             False            False
# 1011       False  False              False             False            False
# 1012       False  False              False             False            False
#
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0           False
# Date                 False
# Natural_Gas_Price    False
# Natural_Gas_Vol.      True
# Crude_oil_Price      False
# Crude_oil_Vol.        True
# Copper_Price         False
# Copper_Vol.           True
# Bitcoin_Price        False
# Bitcoin_Vol.         False
# Platinum_Price       False
# Platinum_Vol.         True
# Ethereum_Price       False
# Ethereum_Vol.        False
# S&P_500_Price        False
# Nasdaq_100_Price     False
# Nasdaq_100_Vol.       True
# Apple_Price          False
# Apple_Vol.           False
# Tesla_Price          False
# Tesla_Vol.           False
# Microsoft_Price      False
# Microsoft_Vol.       False
# Silver_Price         False
# Silver_Vol.           True
# Google_Price         False
# Google_Vol.          False
# Nvidia_Price         False
# Nvidia_Vol.          False
# Berkshire_Price      False
# Berkshire_Vol.       False
# Netflix_Price        False
# Netflix_Vol.         False
# Amazon_Price         False
# ...

# %%
#Checking the null values
df[df['Natural_Gas_Vol.'].isna()==1]
# Out:
#      Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0             0    2/2/2024              2.079               NaN
# 352         352    8/9/2022              7.954               NaN
# 394         394    8/7/2022              6.034               NaN
# 440         440  27-04-2022              7.339               NaN
#
#      Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  \
# 0              72.28             NaN        3.8215          NaN     43,194.70
# 352            83.54        342760.0        3.5220       7240.0     19,317.40
# 394           104.79        327460.0        3.5275       1390.0     21,611.20
# 440           102.02        278780.0        4.4985        600.0     39,243.00
#
#      Bitcoin_Vol.  ... Berkshire_Price  Berkshire_Vol. Netflix_Price  \
# 0           42650  ...        5,89,498           10580        564.64
# 352        291430  ...        4,26,850            2100        227.44
# ...

# %%
#Filling the Null Values with 0
df['Natural_Gas_Vol.']=df['Natural_Gas_Vol.'].fillna(0)

# %%
df['Crude_oil_Vol.']=df['Natural_Gas_Vol.'].fillna(0)

# %%
df['Copper_Vol.']=df['Copper_Vol.'].fillna(0)

# %%
df['Platinum_Vol.']=df['Platinum_Vol.'].fillna(0)

# %%
df['Nasdaq_100_Vol.']=df['Nasdaq_100_Vol.'].fillna(0)

# %%
df['Silver_Vol.']=df['Silver_Vol.'].fillna(0)

# %%
df['Gold_Vol.']=df['Gold_Vol.'].fillna(0)

# %%
df.isnull().any()
# Out:
# Unnamed: 0           False
# Date                 False
# Natural_Gas_Price    False
# Natural_Gas_Vol.     False
# Crude_oil_Price      False
# Crude_oil_Vol.       False
# Copper_Price         False
# Copper_Vol.          False
# Bitcoin_Price        False
# Bitcoin_Vol.         False
# Platinum_Price       False
# Platinum_Vol.        False
# Ethereum_Price       False
# Ethereum_Vol.        False
# S&P_500_Price        False
# Nasdaq_100_Price     False
# Nasdaq_100_Vol.      False
# Apple_Price          False
# Apple_Vol.           False
# Tesla_Price          False
# Tesla_Vol.           False
# Microsoft_Price      False
# Microsoft_Vol.       False
# Silver_Price         False
# Silver_Vol.          False
# Google_Price         False
# Google_Vol.          False
# Nvidia_Price         False
# Nvidia_Vol.          False
# Berkshire_Price      False
# Berkshire_Vol.       False
# Netflix_Price        False
# Netflix_Vol.         False
# Amazon_Price         False
# ...

# %%
#Checking Duplicate Values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1008    False
# 1009    False
# 1010    False
# 1011    False
# 1012    False
# Length: 1013, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   object
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   object
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   object
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   object
#  15  Nasdaq_100_Price   1013 non-null   object
# ...

# %%
#Changing the data type 
df['Bitcoin_Price'] = df['Bitcoin_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   object
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   object
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   object
#  15  Nasdaq_100_Price   1013 non-null   object
# ...

# %%
df['Platinum_Price'] = df['Platinum_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   object
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   object
#  15  Nasdaq_100_Price   1013 non-null   object
# ...

# %%
df['Ethereum_Price'] = df['Ethereum_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   float64
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   object
#  15  Nasdaq_100_Price   1013 non-null   object
# ...

# %%
df['S&P_500_Price'] = df['S&P_500_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   float64
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   float64
# ...

# %%
df['Nasdaq_100_Price'] = df['Nasdaq_100_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   float64
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   float64
# ...

# %%
df['Berkshire_Price'] = df['Berkshire_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   float64
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   float64
# ...

# %%
df['Gold_Price'] = df['Gold_Price'].str.replace(',', '').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1013 non-null   int64
#  1   Date               1013 non-null   object
#  2   Natural_Gas_Price  1013 non-null   float64
#  3   Natural_Gas_Vol.   1013 non-null   float64
#  4   Crude_oil_Price    1013 non-null   float64
#  5   Crude_oil_Vol.     1013 non-null   float64
#  6   Copper_Price       1013 non-null   float64
#  7   Copper_Vol.        1013 non-null   float64
#  8   Bitcoin_Price      1013 non-null   float64
#  9   Bitcoin_Vol.       1013 non-null   int64
#  10  Platinum_Price     1013 non-null   float64
#  11  Platinum_Vol.      1013 non-null   float64
#  12  Ethereum_Price     1013 non-null   float64
#  13  Ethereum_Vol.      1013 non-null   int64
#  14  S&P_500_Price      1013 non-null   float64
# ...

# %%
#Exporting the file
df.to_csv("/Users/meenakshisundaramn/Desktop/DATA/USStockMarketDataset.csv", index=False)
